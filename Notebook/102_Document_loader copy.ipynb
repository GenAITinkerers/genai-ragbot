# %% [markdown]
# ### Explore RAG components

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader, PyPDFLoader

# %% [markdown]
# #### Data Directory Folder

# %%
# Directory where your local TXT/PDF files are stored
DATA_DIRECTORY = "../data_source"

# %% [markdown]
# Directory Loader is used for loading the documents

# %%
pdf_loader = DirectoryLoader(
            DATA_DIRECTORY,
            glob="**/*.pdf",
            loader_cls=PyPDFLoader,
            silent_errors=True
)

# %%
pdf_documents = pdf_loader.load()
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 45 0 (offset 0)
# Ignoring wrong pointing object 47 0 (offset 0)

# %%
pdf_documents
# Out:
# [Document(metadata={'source': '../data_source/deekshitulu_resume.pdf', 'page': 0, 'page_label': '1'}, page_content='V  S  Deekshitulu  Mantha  \nBengaluru,  Karnataka,  India                                                                                                                                       \n+91-9886508907\n \n|\n \nsri.deek@gmail.com\n \nProfessional  Experience  \n●  Working  in  Motorola  Mobility  since  2005,  at  different  software  development/engineer  \nroles,\n \ncurrently\n \nas\n \nAdvisory\n \nEngineer.\n \nEducation  \n●  MTech  in  CSE  from  IIT  Guwahati;   June  2005;   Professional  Summary  \n●  19.5  years  of  experience  in  the  full  software  engineering  lifecycle,  specializing  in  Android  \nnative\n \napp\n \ndevelopment\n \nfor\n \nthe\n \nlast\n \n14\n \nyears.\n ●  Adept  at  steering  cross-functional  and  globally  distributed  teams,  managing  stakeholder  \nrelationships\n \nwith\n \nmajor\n \nNorth\n \nAmerican\n \ncarriers,
# ...

# %% [markdown]
# Text Loader is load the text documents.

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
txt_loader = DirectoryLoader(
            DATA_DIRECTORY,
            glob="**/*.txt",
            loader_cls=TextLoader,
            silent_errors=True
        )

# %%
txt_documents = txt_loader.load()

# %%
txt_documents
# Out:
# [Document(metadata={'source': '../data_source/requirements.txt'}, page_content='# Core framework for UI\nstreamlit==1.37.1\n\n# LangChain core packages (required for text splitters and document loaders)\nlangchain-core==0.3.55\nlangchain-community==0.3.16\nlangchain-text-splitters==0.3.5\n\n# Vector database and embeddings\nlangchain_chroma==0.2.2\nchromadb>=0.4.0\nsentence-transformers>=2.2.0\n\n# Document processing (for PyPDFLoader and TextLoader)\npypdf>=3.17.0\n\n# Performance optimization (required by sentence-transformers and chromadb)\nnumpy>=1.24.0\n\n\n# Core framework for UI\nstreamlit==1.37.1\n\n# LangChain core packages (required for text splitters and document loaders)\nlangchain-core==0.3.55\nlangchain-community==0.3.16\nlangchain-text-splitters==0.3.5\n\n# Vector database and embeddings\nlangchain_chroma==0.2.2\nchromadb>=0.4.0\nsentence-transformers>=2.2.0\n\n# Document processing (for PyPDFLoader and TextLoader)\npypdf>=3.17.0\n\n# Performance optimization (required
# ...

# %%
documents = pdf_documents + txt_documents

# %%
documents
# Out:
# [Document(metadata={'source': '../data_source/deekshitulu_resume.pdf', 'page': 0, 'page_label': '1'}, page_content='V  S  Deekshitulu  Mantha  \nBengaluru,  Karnataka,  India                                                                                                                                       \n+91-9886508907\n \n|\n \nsri.deek@gmail.com\n \nProfessional  Experience  \n●  Working  in  Motorola  Mobility  since  2005,  at  different  software  development/engineer  \nroles,\n \ncurrently\n \nas\n \nAdvisory\n \nEngineer.\n \nEducation  \n●  MTech  in  CSE  from  IIT  Guwahati;   June  2005;   Professional  Summary  \n●  19.5  years  of  experience  in  the  full  software  engineering  lifecycle,  specializing  in  Android  \nnative\n \napp\n \ndevelopment\n \nfor\n \nthe\n \nlast\n \n14\n \nyears.\n ●  Adept  at  steering  cross-functional  and  globally  distributed  teams,  managing  stakeholder  \nrelationships\n \nwith\n \nmajor\n \nNorth\n \nAmerican\n \ncarriers,
# ...

# %%
print(f"Loaded {len(documents)} documents (PDFs and TXTs).")
# Out:
# Loaded 12 documents (PDFs and TXTs).

# %%
## Embedding model initialization and document loading

# %%
from langchain_community.embeddings import SentenceTransformerEmbeddings

# %%
embedding_model = SentenceTransformerEmbeddings(model_name='all-MiniLM-L6-v2')
# Out:
# /var/folders/8f/y7wfy0tj7mb_5ppmq8jdkg9h0000gn/T/ipykernel_94831/1488663231.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = SentenceTransformerEmbeddings(model_name='all-MiniLM-L6-v2')

# %%
# Text splitting

# %%
# for splitting text into manageable chunks Next session
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
documents1 = 'I am Sanjeev.I am a Data Scientist.'

# %%
text_splitter = RecursiveCharacterTextSplitter(is_separator_regex='.', chunk_size=1000, chunk_overlap=200)
chunked_documents = text_splitter.split_documents(documents)

# %%
print(f"Split into {len(chunked_documents)} chunks.")
# Out:
# Split into 53 chunks.

# %%
chunked_documents
# Out:
# [Document(metadata={'source': '../data_source/deekshitulu_resume.pdf', 'page': 0, 'page_label': '1'}, page_content='V  S  Deekshitulu  Mantha  \nBengaluru,  Karnataka,  India                                                                                                                                       \n+91-9886508907\n \n|\n \nsri.deek@gmail.com\n \nProfessional  Experience  \n●  Working  in  Motorola  Mobility  since  2005,  at  different  software  development/engineer  \nroles,\n \ncurrently\n \nas\n \nAdvisory\n \nEngineer.\n \nEducation  \n●  MTech  in  CSE  from  IIT  Guwahati;   June  2005;   Professional  Summary  \n●  19.5  years  of  experience  in  the  full  software  engineering  lifecycle,  specializing  in  Android  \nnative\n \napp\n \ndevelopment\n \nfor\n \nthe\n \nlast\n \n14\n \nyears.\n ●  Adept  at  steering  cross-functional  and  globally  distributed  teams,  managing  stakeholder  \nrelationships\n \nwith\n \nmajor\n \nNorth\n \nAmerican\n \ncarriers,
# ...
