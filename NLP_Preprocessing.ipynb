# %% [markdown]
# Text Preprocessing in NLP

# %%
corpus = [
    "I can't wait for the new season of my favorite show!",
    "The COVID-19 pandemic has affected millions of people worldwide.",
    "U.S. stocks fell on Friday after news of rising inflation.",
    "<html><body>Welcome to the website!</body></html>",
    "Python is a great programming language!!! ??"
]

# %% [markdown]
# Text Cleaning

# %%
import re
import string
from bs4 import BeautifulSoup

def clean_text(text):
    text = text.lower()  
    # Lowercase
    #text = re.sub(r'\d+', '', text)  # Remove numbers
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    text = re.sub(r'\W', ' ', text)  # Remove special characters
    text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML tags
    return text

cleaned_corpus = [clean_text(doc) for doc in corpus]
# Out:
# htmlbodywelcome to the websitebodyhtml

# %% [markdown]
# Tokenization

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/sanjeevkumar/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokenized_corpus = [word_tokenize(doc) for doc in cleaned_corpus]
print(tokenized_corpus)
# Out:
# [['i', 'cant', 'wait', 'for', 'the', 'new', 'season', 'of', 'my', 'favorite', 'show'], ['the', 'covid', 'pandemic', 'has', 'affected', 'millions', 'of', 'people', 'worldwide'], ['us', 'stocks', 'fell', 'on', 'friday', 'after', 'news', 'of', 'rising', 'inflation'], ['htmlbodywelcome', 'to', 'the', 'websitebodyhtml'], ['python', 'is', 'a', 'great', 'programming', 'language']]

# %% [markdown]
# Stop Word Removals

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

filtered_corpus = [[word for word in doc if word not in stop_words] for doc in tokenized_corpus]
print(corpus)
print(filtered_corpus)
# Out:
# ["I can't wait for the new season of my favorite show!", 'The COVID-19 pandemic has affected millions of people worldwide.', 'U.S. stocks fell on Friday after news of rising inflation.', '<html><body>Welcome to the website!</body></html>', 'Python is a great programming language!!! ??']
# [['I', 'ca', "n't", 'wait', 'new', 'season', 'favorite', 'show', '!'], ['The', 'COVID-19', 'pandemic', 'affected', 'millions', 'people', 'worldwide', '.'], ['U.S.', 'stocks', 'fell', 'Friday', 'news', 'rising', 'inflation', '.'], ['<', 'html', '>', '<', 'body', '>', 'Welcome', 'website', '!', '<', '/body', '>', '<', '/html', '>'], ['Python', 'great', 'programming', 'language', '!', '!', '!', '?', '?']]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sanjeevkumar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Stemming and Lemmatization

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('wordnet')

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stemmed_corpus = [[stemmer.stem(word) for word in doc] for doc in filtered_corpus]
lemmatized_corpus = [[lemmatizer.lemmatize(word,pos='v') for word in doc] for doc in filtered_corpus]
print(stemmed_corpus)
print(lemmatized_corpus)
# Out:
# [['i', 'ca', "n't", 'wait', 'new', 'season', 'favorit', 'show', '!'], ['the', 'covid-19', 'pandem', 'affect', 'million', 'peopl', 'worldwid', '.'], ['u.s.', 'stock', 'fell', 'friday', 'news', 'rise', 'inflat', '.'], ['<', 'html', '>', '<', 'bodi', '>', 'welcom', 'websit', '!', '<', '/bodi', '>', '<', '/html', '>'], ['python', 'great', 'program', 'languag', '!', '!', '!', '?', '?']]
# [['I', 'ca', "n't", 'wait', 'new', 'season', 'favorite', 'show', '!'], ['The', 'COVID-19', 'pandemic', 'affect', 'millions', 'people', 'worldwide', '.'], ['U.S.', 'stock', 'fell', 'Friday', 'news', 'rise', 'inflation', '.'], ['<', 'html', '>', '<', 'body', '>', 'Welcome', 'website', '!', '<', '/body', '>', '<', '/html', '>'], ['Python', 'great', 'program', 'language', '!', '!', '!', '?', '?']]
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sanjeevkumar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Handling Contractions

# %% [markdown]
# I can't go to work.

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in /opt/anaconda3/envs/gen-ai/lib/python3.12/site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /opt/anaconda3/envs/gen-ai/lib/python3.12/site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /opt/anaconda3/envs/gen-ai/lib/python3.12/site-packages (from textsearch>=0.0.21->contractions) (0.3.3)
# Requirement already satisfied: pyahocorasick in /opt/anaconda3/envs/gen-ai/lib/python3.12/site-packages (from textsearch>=0.0.21->contractions) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import contractions

expanded_corpus = [contractions.fix(doc) for doc in cleaned_corpus]
print(expanded_corpus)
# Out:
# ['i cannot wait for the new season of my favorite show', 'the covid pandemic has affected millions of people worldwide', 'us stocks fell on friday after news of rising inflation', 'htmlbodywelcome to the websitebodyhtml', 'python is a great programming language ']

# %% [markdown]
# Handling Emojis and Emoticons

# %%
document = ["I can't go to work 😄"]

# %%
import emoji

emoji_corpus = [emoji.demojize(doc) for doc in document]
print(emoji_corpus)
# Out:
# ["I can't go to work :grinning_face_with_smiling_eyes:"]

# %% [markdown]
# Spell Checking

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in /opt/anaconda3/envs/gen-ai/lib/python3.12/site-packages (0.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
docs = ["I can not go to offics", "I can't go to work 😄"]

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
corrected_corpus = [[spell.correction(word) for word in doc.split()] for doc in docs]
print(corrected_corpus)
# Out:
# [['I', 'can', 'not', 'go', 'to', 'office'], ['I', "can't", 'go', 'to', 'work', 'i']]
